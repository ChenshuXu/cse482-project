# %%
import pandas as pd

# %% [markdown]
# ## Process 2013 data

# %%
crime_data_2013 = pd.read_pickle("crime_data_traffic_weather_income_2013.pkl")
crime_data_2013
# Out:
#                     Date            Primary Type  District  Community Area  \
# 0    2013-01-20 18:00:00      DECEPTIVE PRACTICE        10            29.0
# 1    2013-07-03 18:10:00               NARCOTICS        10            29.0
# 2    2013-03-02 02:45:00                 BATTERY        10            29.0
# 3    2013-06-21 18:27:00               NARCOTICS        10            29.0
# 4    2013-01-09 10:30:00                   THEFT        10            29.0
# 5    2013-01-18 07:00:00         CRIMINAL DAMAGE        10            29.0
# 6    2013-01-23 02:59:00                   THEFT        10            29.0
# 7    2013-01-24 16:30:00     MOTOR VEHICLE THEFT        10            29.0
# 8    2013-01-25 14:20:00               NARCOTICS        10            29.0
# 9    2013-01-27 19:00:00                 BATTERY        10            29.0
# 10   2013-01-28 08:00:00                 BATTERY        10            29.0
# ...

# %%
day = []

for index,row in crime_data_2013.iterrows():
    day.append(row['Date'].strftime("%Y-%m-%d"))

crime_data_2013['Day'] = day
crime_data_2013
# Out:
#                     Date            Primary Type  District  Community Area  \
# 0    2013-01-20 18:00:00      DECEPTIVE PRACTICE        10            29.0
# 1    2013-07-03 18:10:00               NARCOTICS        10            29.0
# 2    2013-03-02 02:45:00                 BATTERY        10            29.0
# 3    2013-06-21 18:27:00               NARCOTICS        10            29.0
# 4    2013-01-09 10:30:00                   THEFT        10            29.0
# 5    2013-01-18 07:00:00         CRIMINAL DAMAGE        10            29.0
# 6    2013-01-23 02:59:00                   THEFT        10            29.0
# 7    2013-01-24 16:30:00     MOTOR VEHICLE THEFT        10            29.0
# 8    2013-01-25 14:20:00               NARCOTICS        10            29.0
# 9    2013-01-27 19:00:00                 BATTERY        10            29.0
# 10   2013-01-28 08:00:00                 BATTERY        10            29.0
# ...

# %%
crime_rate_2013 = pd.read_pickle("2013 crime_rate.pkl")
crime_rate_2013
# Out:
#               Day Time Period  District  Crime Rate
# 0      2013-01-01   afternoon         1    0.005490
# 1      2013-01-01     evening         1    0.013333
# 2      2013-01-01     morning         1    0.007843
# 3      2013-01-01   afternoon         2    0.012549
# 4      2013-01-01     evening         2    0.017255
# 5      2013-01-01     morning         2    0.015686
# 6      2013-01-01   afternoon         3    0.008627
# 7      2013-01-01     evening         3    0.025098
# 8      2013-01-01     morning         3    0.017255
# 9      2013-01-01   afternoon         4    0.009412
# 10     2013-01-01     evening         4    0.024314
# 11     2013-01-01     morning         4    0.013333
# 12     2013-01-01   afternoon         5    0.010196
# 13     2013-01-01     evening         5    0.015686
# 14     2013-01-01     morning         5    0.012549
# 15     2013-01-01   afternoon         6    0.016471
# 16     2013-01-01     evening         6    0.036078
# ...

# %%
df_2013 = pd.merge(crime_data_2013,crime_rate_2013,left_on=['District','Day','Time Period'],right_on=['District','Day','Time Period'])
df_2013
# Out:
#                     Date            Primary Type  District  Community Area  \
# 0    2013-01-20 18:00:00      DECEPTIVE PRACTICE        10            29.0
# 1    2013-07-03 18:10:00               NARCOTICS        10            29.0
# 2    2013-03-02 02:45:00                 BATTERY        10            29.0
# 3    2013-06-21 18:27:00               NARCOTICS        10            29.0
# 4    2013-01-09 10:30:00                   THEFT        10            29.0
# 5    2013-01-18 07:00:00         CRIMINAL DAMAGE        10            29.0
# 6    2013-01-18 08:45:00       CRIMINAL TRESPASS        10            31.0
# 7    2013-01-23 02:59:00                   THEFT        10            29.0
# 8    2013-01-24 16:30:00     MOTOR VEHICLE THEFT        10            29.0
# 9    2013-01-25 14:20:00               NARCOTICS        10            29.0
# 10   2013-01-27 19:00:00                 BATTERY        10            29.0
# ...

# %%
dayOfWeek = []

for index,row in df_2013.iterrows():
    day = row['Date'].strftime("%a")
    if day == 'Sun' or day == 'Sat':
        dayOfWeek.append('weekend')
    else:
        dayOfWeek.append('weekday')
dayOfWeek

df_2013['dayOfWeek'] = dayOfWeek

# %%
df_2013.columns
# Out:
# Index(['Date', 'Primary Type', 'District', 'Community Area', 'Latitude',
#        'Longitude', 'Time Period', 'SPEED', 'Average Traffic condition',
#        'SEGMENTID', 'WEATHER', 'PER CAPITA INCOME', 'Day', 'Crime Rate',
#        'dayOfWeek'],
#       dtype='object')

# %%
store_2013 = df_2013.drop(columns=['Primary Type', 'Latitude',
       'Longitude','SPEED'])
store_2013
# Out:
#                     Date  District  Community Area Time Period  \
# 0    2013-01-20 18:00:00        10            29.0   afternoon
# 1    2013-07-03 18:10:00        10            29.0   afternoon
# 2    2013-03-02 02:45:00        10            29.0     evening
# 3    2013-06-21 18:27:00        10            29.0   afternoon
# 4    2013-01-09 10:30:00        10            29.0     morning
# 5    2013-01-18 07:00:00        10            29.0     morning
# 6    2013-01-18 08:45:00        10            31.0     morning
# 7    2013-01-23 02:59:00        10            29.0     evening
# 8    2013-01-24 16:30:00        10            29.0   afternoon
# 9    2013-01-25 14:20:00        10            29.0   afternoon
# 10   2013-01-27 19:00:00        10            29.0   afternoon
# 11   2013-01-28 08:00:00        10            29.0     morning
# 12   2013-01-30 16:00:00        10            29.0   afternoon
# 13   2013-02-13 21:10:00        10            29.0     evening
# ...

# %%
store_2013.to_pickle("data_final_2013.pkl")

# %% [markdown]
# ## Process 2014 data

# %%
crime_data_2014 = pd.read_pickle("crime_data_traffic_weather_income_2014.pkl")
crime_data_2014
# Out:
#                 Datetime         Primary Type  District Community Area  \
# 0    2014-11-19 10:00:00   DECEPTIVE PRACTICE        18              8
# 1    2014-11-19 12:30:00                THEFT        18              8
# 2    2014-11-19 17:45:00                THEFT        18              8
# 3    2014-03-06 03:30:00      CRIMINAL DAMAGE        18              8
# 4    2014-09-30 00:14:00                THEFT        18              8
# 5    2014-04-15 23:00:00        OTHER OFFENSE        18              8
# 6    2014-01-01 05:18:00                THEFT        18              8
# 7    2014-01-01 02:00:00              BATTERY        18              8
# 8    2014-01-01 21:50:00                THEFT        18              8
# 9    2014-01-01 22:00:00                THEFT        18              8
# 10   2014-01-01 17:00:00   DECEPTIVE PRACTICE        18              8
# 11   2014-12-28 12:45:00   DECEPTIVE PRACTICE        18              8
# ...

# %%
day = []

for index,row in crime_data_2014.iterrows():
    day.append(row['Datetime'].strftime("%Y-%m-%d"))

crime_data_2014['Day'] = day
crime_data_2014
# Out:
#                 Datetime         Primary Type  District Community Area  \
# 0    2014-11-19 10:00:00   DECEPTIVE PRACTICE        18              8
# 1    2014-11-19 12:30:00                THEFT        18              8
# 2    2014-11-19 17:45:00                THEFT        18              8
# 3    2014-03-06 03:30:00      CRIMINAL DAMAGE        18              8
# 4    2014-09-30 00:14:00                THEFT        18              8
# 5    2014-04-15 23:00:00        OTHER OFFENSE        18              8
# 6    2014-01-01 05:18:00                THEFT        18              8
# 7    2014-01-01 02:00:00              BATTERY        18              8
# 8    2014-01-01 21:50:00                THEFT        18              8
# 9    2014-01-01 22:00:00                THEFT        18              8
# 10   2014-01-01 17:00:00   DECEPTIVE PRACTICE        18              8
# 11   2014-12-28 12:45:00   DECEPTIVE PRACTICE        18              8
# ...

# %%
crime_rate_2014 = pd.read_pickle("2014 crime_rate.pkl")
crime_rate_2014
# Out:
#               Day Time Period  District  Crime Rate
# 0      2014-01-01   afternoon         1    0.007071
# 1      2014-01-01     evening         1    0.017172
# 2      2014-01-01     morning         1    0.009091
# 3      2014-01-01   afternoon         2    0.009091
# 4      2014-01-01     evening         2    0.021212
# 5      2014-01-01     morning         2    0.010101
# 6      2014-01-01   afternoon         3    0.015152
# 7      2014-01-01     evening         3    0.020202
# 8      2014-01-01     morning         3    0.014141
# 9      2014-01-01   afternoon         4    0.015152
# 10     2014-01-01     evening         4    0.022222
# 11     2014-01-01     morning         4    0.015152
# 12     2014-01-01   afternoon         5    0.013131
# 13     2014-01-01     evening         5    0.025253
# 14     2014-01-01     morning         5    0.015152
# 15     2014-01-01   afternoon         6    0.016162
# 16     2014-01-01     evening         6    0.036364
# ...

# %%
df_2014 = pd.merge(crime_data_2014,crime_rate_2014,left_on=['District','Day','Time Period'],right_on=['District','Day','Time Period'])
df_2014
# Out:
#                 Datetime         Primary Type  District Community Area  \
# 0    2014-11-19 10:00:00   DECEPTIVE PRACTICE        18              8
# 1    2014-11-19 12:30:00                THEFT        18              8
# 2    2014-11-19 17:45:00                THEFT        18              8
# 3    2014-03-06 03:30:00      CRIMINAL DAMAGE        18              8
# 4    2014-09-30 00:14:00                THEFT        18              8
# 5    2014-04-15 23:00:00        OTHER OFFENSE        18              8
# 6    2014-01-01 05:18:00                THEFT        18              8
# 7    2014-01-01 02:00:00              BATTERY        18              8
# 8    2014-01-01 21:50:00                THEFT        18              8
# 9    2014-01-01 22:00:00                THEFT        18              8
# 10   2014-01-01 17:00:00   DECEPTIVE PRACTICE        18              8
# 11   2014-12-28 12:45:00   DECEPTIVE PRACTICE        18              8
# ...

# %%
dayOfWeek = []

for index,row in df_2014.iterrows():
    day = row['Datetime'].strftime("%a")
    if day == 'Sun' or day == 'Sat':
        dayOfWeek.append('weekend')
    else:
        dayOfWeek.append('weekday')

df_2014['dayOfWeek'] = dayOfWeek

# %%
store_2014 = df_2014.drop(columns=['Primary Type', 'Latitude',
       'Longitude','SPEED'])

store_2014 = store_2014.rename(columns={'Datetime':'Date'})
store_2014
# Out:
#                     Date  District Community Area Time Period  \
# 0    2014-11-19 10:00:00        18              8     morning
# 1    2014-11-19 12:30:00        18              8   afternoon
# 2    2014-11-19 17:45:00        18              8   afternoon
# 3    2014-03-06 03:30:00        18              8     evening
# 4    2014-09-30 00:14:00        18              8     evening
# 5    2014-04-15 23:00:00        18              8     evening
# 6    2014-01-01 05:18:00        18              8     morning
# 7    2014-01-01 02:00:00        18              8     evening
# 8    2014-01-01 21:50:00        18              8     evening
# 9    2014-01-01 22:00:00        18              8     evening
# 10   2014-01-01 17:00:00        18              8   afternoon
# 11   2014-12-28 12:45:00        18              8   afternoon
# 12   2014-02-18 14:00:00        18              8   afternoon
# 13   2014-02-18 08:00:00        18              8     morning
# ...

# %%
store_2014.to_pickle("data_final_2014.pkl")
