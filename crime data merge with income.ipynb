# %%
import pandas as pd

# %%
crime_data_2013 = pd.read_pickle("crime_data_traffic_weather_2013.pkl")
crime_data_2013
# Out:
#                     Date                Primary Type  District  \
# 0    2013-01-20 18:00:00          DECEPTIVE PRACTICE        10
# 1    2013-01-20 01:50:00                     BATTERY        12
# 2    2013-01-20 03:00:00                       THEFT        14
# 3    2013-01-20 04:10:00                     BATTERY         1
# 4    2013-01-20 04:00:00                     ROBBERY         6
# 5    2013-01-20 10:35:00                   NARCOTICS         9
# 6    2013-01-20 23:15:00           CRIMINAL TRESPASS         6
# 7    2013-01-20 16:30:00             CRIMINAL DAMAGE         8
# 8    2013-01-20 23:55:00                       THEFT         4
# 9    2013-01-20 16:00:00         MOTOR VEHICLE THEFT         9
# 10   2013-01-20 16:00:00             CRIMINAL DAMAGE         8
# 11   2013-01-20 12:00:00                       THEFT         8
# 12   2013-01-20 23:00:00          DECEPTIVE PRACTICE         6
# 13   2013-10-08 08:30:00          DECEPTIVE PRACTICE        18
# ...

# %%
income_data = pd.read_pickle("Income_subData.pkl")
income_data
# Out:
#     Community Area Number PER CAPITA INCOME
# 0                     1.0            Medium
# 1                     2.0            Medium
# 2                     3.0              High
# 3                     4.0              High
# 4                     5.0              High
# 5                     6.0              High
# 6                     7.0              High
# 7                     8.0              High
# 8                     9.0              High
# 9                    10.0              High
# 10                   11.0              High
# 11                   12.0              High
# 12                   13.0              High
# 13                   14.0            Medium
# 14                   15.0            Medium
# 15                   16.0              High
# 16                   17.0              High
# 17                   18.0            Medium
# 18                   19.0               Low
# 19                   20.0               Low
# ...

# %%
merged_data = crime_data_2013.merge(income_data, left_on="Community Area", right_on="Community Area Number")

# %%
merged_data = merged_data.drop(columns=['Community Area Number'])

# %%
merged_data
# Out:
#                     Date            Primary Type  District  Community Area  \
# 0    2013-01-20 18:00:00      DECEPTIVE PRACTICE        10            29.0
# 1    2013-07-03 18:10:00               NARCOTICS        10            29.0
# 2    2013-03-02 02:45:00                 BATTERY        10            29.0
# 3    2013-06-21 18:27:00               NARCOTICS        10            29.0
# 4    2013-01-09 10:30:00                   THEFT        10            29.0
# 5    2013-01-18 07:00:00         CRIMINAL DAMAGE        10            29.0
# 6    2013-01-23 02:59:00                   THEFT        10            29.0
# 7    2013-01-24 16:30:00     MOTOR VEHICLE THEFT        10            29.0
# 8    2013-01-25 14:20:00               NARCOTICS        10            29.0
# 9    2013-01-27 19:00:00                 BATTERY        10            29.0
# 10   2013-01-28 08:00:00                 BATTERY        10            29.0
# ...

# %%
merged_data.to_pickle("crime_data_traffic_weather_income_2013.pkl")

# %%
crime_data_2014 = pd.read_pickle("crime_data_traffic_weather_2014.pkl")
crime_data_2014
# Out:
#                 Datetime                      Primary Type  District  \
# 0    2014-11-19 10:00:00                DECEPTIVE PRACTICE        18
# 1    2014-11-19 09:30:00                             THEFT        12
# 2    2014-11-19 12:30:00                             THEFT        18
# 3    2014-11-19 14:00:00                           ROBBERY         4
# 4    2014-11-19 17:45:00                             THEFT        18
# 5    2014-11-19 16:41:00                   CRIMINAL DAMAGE        22
# 6    2014-11-19 23:40:00                         NARCOTICS         8
# 7    2014-11-19 07:00:00                             THEFT         9
# 8    2014-03-06 12:00:00                             THEFT        12
# 9    2014-03-06 09:45:00                 CRIMINAL TRESPASS         1
# 10   2014-03-06 16:05:00                         NARCOTICS         6
# 11   2014-03-06 06:30:00                          BURGLARY         8
# 12   2014-03-06 21:00:00                           BATTERY         9
# ...

# %%
merged_data_2014 = crime_data_2014.merge(income_data, left_on="Community Area", right_on="Community Area Number")
merged_data_2014 = merged_data_2014.drop(columns=['Community Area Number'])

# %%
merged_data_2014
# Out:
#                 Datetime         Primary Type  District Community Area  \
# 0    2014-11-19 10:00:00   DECEPTIVE PRACTICE        18              8
# 1    2014-11-19 12:30:00                THEFT        18              8
# 2    2014-11-19 17:45:00                THEFT        18              8
# 3    2014-03-06 03:30:00      CRIMINAL DAMAGE        18              8
# 4    2014-09-30 00:14:00                THEFT        18              8
# 5    2014-04-15 23:00:00        OTHER OFFENSE        18              8
# 6    2014-01-01 05:18:00                THEFT        18              8
# 7    2014-01-01 02:00:00              BATTERY        18              8
# 8    2014-01-01 21:50:00                THEFT        18              8
# 9    2014-01-01 22:00:00                THEFT        18              8
# 10   2014-01-01 17:00:00   DECEPTIVE PRACTICE        18              8
# 11   2014-12-28 12:45:00   DECEPTIVE PRACTICE        18              8
# ...

# %%
merged_data.to_pickle("crime_data_traffic_weather_income_2014.pkl")
