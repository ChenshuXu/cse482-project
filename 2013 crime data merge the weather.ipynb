# %% [markdown]
# # 2013 crime data merge the weather data

# %%
import pandas as pd

crime_data = pd.read_pickle("crime_merge_traffic_2013.pkl")
crime_data
# Out:
#                     Date                      Primary Type  District  \
# 0    2013-01-20 18:00:00                DECEPTIVE PRACTICE        10
# 1    2013-10-08 08:30:00                DECEPTIVE PRACTICE        18
# 2    2013-05-28 08:00:00                DECEPTIVE PRACTICE         9
# 3    2013-11-10 09:00:00                DECEPTIVE PRACTICE         8
# 4    2013-05-01 08:00:00                DECEPTIVE PRACTICE         9
# 5    2013-07-03 00:01:00                DECEPTIVE PRACTICE         8
# 6    2013-06-01 10:00:00                DECEPTIVE PRACTICE        18
# 7    2013-01-01 09:00:00                DECEPTIVE PRACTICE         1
# 8    2013-01-26 04:00:00                          HOMICIDE         9
# 9    2013-01-26 04:00:00                          HOMICIDE         9
# 10   2013-03-02 04:00:00                          HOMICIDE         6
# 11   2013-06-21 14:39:00                          HOMICIDE        18
# 12   2013-12-21 19:20:00                          HOMICIDE         6
# ...

# %%
crime_data.columns
# Out:
# Index(['Date', 'Primary Type', 'District', 'Community Area', 'Latitude',
#        'Longitude', 'Time Period', 'SPEED', 'Average Traffic condition',
#        'SEGMENTID'],
#       dtype='object')

# %%
weather_data = pd.read_pickle("Weather_Type_13_subData.pkl")
weather_data
# Out:
#            DATE WEATHER
# 1    2013-01-01   Sunny
# 2    2013-01-02   Sunny
# 3    2013-01-03  Cloudy
# 4    2013-01-04  Cloudy
# 5    2013-01-05   Sunny
# 6    2013-01-06  Cloudy
# 7    2013-01-07   Sunny
# 8    2013-01-08  Cloudy
# 9    2013-01-09    Rain
# 10   2013-01-10   Sunny
# 11   2013-01-11   Sunny
# 12   2013-01-12    Snow
# 13   2013-01-13    Snow
# 14   2013-01-14   Sunny
# 15   2013-01-15   Sunny
# 16   2013-01-16    Snow
# 17   2013-01-17   Sunny
# 18   2013-01-18   Sunny
# 19   2013-01-19  Cloudy
# 20   2013-01-20  Cloudy
# 21   2013-01-21    Snow
# 22   2013-01-22  Cloudy
# 23   2013-01-23   Sunny
# 24   2013-01-24   Sunny
# 25   2013-01-25  Cloudy
# 26   2013-01-26   Sunny
# 27   2013-01-27    Snow
# 28   2013-01-28   Sunny
# 29   2013-01-29  Cloudy
# 30   2013-01-30  Cloudy
# ..          ...     ...
# 336  2013-12-02   Sunny
# 337  2013-12-03   Sunny
# 338  2013-12-04   Sunny
# 339  2013-12-05   Sunny
# 340  2013-12-06   Sunny
# 341  2013-12-07   Sunny
# ...

# %% [markdown]
# #### Merge crime data with weather data on date

# %%
crime_data["DATE"] = crime_data["Date"].dt.strftime('%Y-%m-%d')

# %%
crime_data
# Out:
#                     Date                      Primary Type  District  \
# 0    2013-01-20 18:00:00                DECEPTIVE PRACTICE        10
# 1    2013-10-08 08:30:00                DECEPTIVE PRACTICE        18
# 2    2013-05-28 08:00:00                DECEPTIVE PRACTICE         9
# 3    2013-11-10 09:00:00                DECEPTIVE PRACTICE         8
# 4    2013-05-01 08:00:00                DECEPTIVE PRACTICE         9
# 5    2013-07-03 00:01:00                DECEPTIVE PRACTICE         8
# 6    2013-06-01 10:00:00                DECEPTIVE PRACTICE        18
# 7    2013-01-01 09:00:00                DECEPTIVE PRACTICE         1
# 8    2013-01-26 04:00:00                          HOMICIDE         9
# 9    2013-01-26 04:00:00                          HOMICIDE         9
# 10   2013-03-02 04:00:00                          HOMICIDE         6
# 11   2013-06-21 14:39:00                          HOMICIDE        18
# 12   2013-12-21 19:20:00                          HOMICIDE         6
# ...

# %%
merged_data = pd.merge(crime_data, weather_data, left_on='DATE', right_on='DATE', how='inner')

# %%
merged_data = merged_data.drop(columns=['DATE'])
merged_data
# Out:
#                     Date                Primary Type  District  \
# 0    2013-01-20 18:00:00          DECEPTIVE PRACTICE        10
# 1    2013-01-20 01:50:00                     BATTERY        12
# 2    2013-01-20 03:00:00                       THEFT        14
# 3    2013-01-20 04:10:00                     BATTERY         1
# 4    2013-01-20 04:00:00                     ROBBERY         6
# 5    2013-01-20 10:35:00                   NARCOTICS         9
# 6    2013-01-20 23:15:00           CRIMINAL TRESPASS         6
# 7    2013-01-20 16:30:00             CRIMINAL DAMAGE         8
# 8    2013-01-20 23:55:00                       THEFT         4
# 9    2013-01-20 16:00:00         MOTOR VEHICLE THEFT         9
# 10   2013-01-20 16:00:00             CRIMINAL DAMAGE         8
# 11   2013-01-20 12:00:00                       THEFT         8
# 12   2013-01-20 23:00:00          DECEPTIVE PRACTICE         6
# 13   2013-10-08 08:30:00          DECEPTIVE PRACTICE        18
# ...

# %%
merged_data.to_pickle("crime_data_traffic_weather_2013.pkl")
